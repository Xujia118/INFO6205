# %% [markdown]
# # 204. Count Primes
# # https://leetcode.com/problems/count-primes/
# # filename: L0204.ipynb

# %%
from time import process_time

# %% [markdown]
# # L0204.py

# %%
############################################################
# L0204.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
# NOTHING CAN BE CHANGED
# 204. Count Primes
# https://leetcode.com/problems/count-primes/
############################################################
class Solution:
    def countPrimes(self, n: int) -> int:
        list = []
        work = [0]
        if True:
            L0204(n, list, work, "up_to_prime")
        if False:
            L0204(n, list, work, "sieve_of_eratosthenes")
        return len(list)


############################################################
#  L0204 class
############################################################
class L0204:
    def __init__(
        self, n: "int", prime_number_list: "list", work: "list of size 1", alg: "string"
    ):
        self._n = n
        self._prime_number_list = (
            prime_number_list  # You need to append this using _append_prime_number
        )
        self._work = work  # You need to increment using _increment_work_done()
        if alg == "up_to_prime":
            self.up_to_primes()
        elif alg == "sieve_of_eratosthenes":
            self.sieve_of_eratosthenes()
        else:
            assert False

    ############################################################
    # All work done goes through this routine.
    # Nothing can be changed
    ###########################################################
    def _increment_work_done(self):
        self._work[0] = self._work[0] + 1

    ############################################################
    # All prime numbers are appended to the list.
    # Nothing can be changed
    ###########################################################
    def _append_prime_number(self, p):
        self._prime_number_list.append(p)

    ##Required function to implement
    def up_to_primes(self) -> "None":
        ## NOTHING CAN BE CHANGED HERE
        ## you cannot call log from Python library
        self._up_to_primes()

    ##Required function to implement
    def sieve_of_eratosthenes(self) -> "None":
        ## NOTHING CAN BE CHANGED HERE
        ## YOU CANNOT CALL math.log from Python library
        self._sieve_of_eratosthenes()

    ############################################################
    # Implement your code BELOW
    # You can have any number of private variables and functions
    # YOU CANNOT CALL math.log from Python library
    ###########################################################
    
    # If a num can't be divided by any prime number, it's a prime number
    def _up_to_primes(self):
        if self._n < 2:
            return 0
        
        if self._n == 2:
            return 1

        # We know 2 is the first prime number
        self._prime_number_list.append(2)

        for num in range(3, self._n, 2): # don't need to check even numbers
            if self._isPrime(num):
                self._append_prime_number(num)
                self._increment_work_done()

    def _isPrime(self, n):
        for primer in self._prime_number_list:
            if primer ** 2 > n:
                break
            if n % primer == 0:
                return False
            self._increment_work_done()
            
        return True
    
    # Most efficient solution
    def _sieve_of_eratosthenes(self):
        if self._n < 2:
            return 0

        sieve = [True] * self._n
        sieve[0] = False
        sieve[1] = False

        # private method to get square root of n
        root = self._get_root(self._n)

        for i in range(2, root + 1):
            if sieve[i] is True:

                factor = 2
                while factor * i < self._n:
                    sieve[factor * i] = False
                    factor += 1

                    self._increment_work_done() # To be verified...
        
        for i, n in enumerate(sieve):
            if n is True:
                self._prime_number_list.append(i)

    # Binary search to get square root. O(logN)
    def _get_root(self, n):
        left, right = 0, n

        while left <= right:
            mid = (left + right) // 2

            if mid ** 2 <= n and (mid + 1) ** 2 > n:
                return mid
            elif mid ** 2 < n:
                left = mid
            else:
                right = mid

            self._increment_work_done()
            
solution = Solution()
print(solution.countPrimes(100))
# Out:
# 25

# %% [markdown]
# # L0204Test.py

# %%
############################################################
# L0204Test.py
# Author: Jagadeesh Vasudevamurthy
# Copyright: Jagadeesh Vasudevamurthy 2024
###########################################################

############################################################
#           NOTHING CAN BE CHANGED IN THIS FILE
###########################################################

############################################################
# All imports
###########################################################
#from L0204 import *
#from time import process_time 

class L0204Test():
    def __init__(self):
        self._testBench()
    
    def _testBench(self):
        self._tests()
        print("ALL TESTS PASSED")

    def _print(self,s:'String',n:'int',ans:'int',steps:'int',num_prime:'int', d:'float'):
        print("---------------",s, " Method-----------------------")    
        assert(num_prime == ans)
        print(n, " has ", num_prime, " Prime. Took", steps, " steps to compute")
        print("Total CPU time in sec =",d)
        

    def _test1(self,n:'int',ans:'int'):
        print("-------------", n , "-------------------------")
        t1_start = process_time()
        up_to_prime_list = []
        work1 = [0]
        L0204(n,up_to_prime_list,work1,"up_to_prime")
        t1_stop = process_time() 
        d = t1_stop - t1_start; 
        self._print("uptoprime",n,ans,work1[0],len(up_to_prime_list),d)
        if (work1[0] == 0):
          print("How did you solve this problem in ", work1[0], "Steps")
          assert(False) ;
        
        t1_start = process_time()
        sieve_prime_number_list  = []
        work2 = [0]
        L0204(n,sieve_prime_number_list,work2,"sieve_of_eratosthenes")
        t1_stop = process_time() 
        d = t1_stop - t1_start; 
        self._print("sieve_of_eratosthenes",n,ans,work2[0],len(sieve_prime_number_list),d)
        if (work2[0] == 0):
          print("How did you solve this problem in ", work2[0], "Steps")
          assert(False) ;
        if (up_to_prime_list != sieve_prime_number_list):
            print("Prime numbers are different between two algorithms")
            assert(False)

    def _tests(self):
        n = [100,1000,10000,100000,1000000]
        a = [25,168,1229,9592,78498]
        j = 0
        for i in n:
            self._test1(i,a[j])
            j = j + 1


############################################################
# main 
# YOU CANNOT CHANGE ANYTHING BELOW
###########################################################
def main():
    print("Testing Prime.py Starts")
    s = L0204Test()
    print("Testing Prime.py ENDS")
############################################################
# numCourses up
###########################################################
if (__name__    == '__main__'):
    main()
# Out:
# Testing Prime.py Starts
# ------------- 100 -------------------------
# --------------- uptoprime  Method-----------------------
# 100  has  25  Prime. Took 131  steps to compute
# Total CPU time in sec = 0.0
# --------------- sieve_of_eratosthenes  Method-----------------------
# 100  has  25  Prime. Took 116  steps to compute
# Total CPU time in sec = 0.0
# ------------- 1000 -------------------------
# --------------- uptoprime  Method-----------------------
# 1000  has  168  Prime. Took 2137  steps to compute
# Total CPU time in sec = 0.0
# --------------- sieve_of_eratosthenes  Method-----------------------
# 1000  has  168  Prime. Took 1551  steps to compute
# Total CPU time in sec = 0.0
# ------------- 10000 -------------------------
# --------------- uptoprime  Method-----------------------
# 10000  has  1229  Prime. Took 36211  steps to compute
# Total CPU time in sec = 0.03125
# --------------- sieve_of_eratosthenes  Method-----------------------
# 10000  has  1229  Prime. Took 18001  steps to compute
# Total CPU time in sec = 0.015625
# ------------- 100000 -------------------------
# --------------- uptoprime  Method-----------------------
# 100000  has  9592  Prime. Took 663620  steps to compute
# Total CPU time in sec = 0.28125
# --------------- sieve_of_eratosthenes  Method-----------------------
# 100000  has  9592  Prime. Took 202163  steps to compute
# Total CPU time in sec = 0.078125
# ------------- 1000000 -------------------------
# --------------- uptoprime  Method-----------------------
# 1000000  has  78498  Prime. Took 13084398  steps to compute
# Total CPU time in sec = 4.046875
# --------------- sieve_of_eratosthenes  Method-----------------------
# 1000000  has  78498  Prime. Took 2197855  steps to compute
# Total CPU time in sec = 0.96875
# ALL TESTS PASSED
# Testing Prime.py ENDS
